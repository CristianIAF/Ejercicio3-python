# %% [markdown]
# ######12 - Un establecimiento está vendiendo combustibles con descuentos variables. Para el etanol, si la cantidad comprada es de hasta 15 litros, el descuento será del 2% por litro. En caso contrario, será del 4% por litro. Para el diésel, si la cantidad comprada es de hasta 15 litros, el descuento será del 3% por litro. En caso contrario, será del 5% por litro. El precio por litro de diésel es de R$ 2,00 y el precio por litro de etanol es de R$ 1,70. Escribe un programa que lea la cantidad de litros vendidos y el tipo de combustible (E para etanol y D para diésel) y calcule el valor a pagar por el cliente. Ten en cuenta algunas sugerencias:
#
# ######El valor del descuento será el producto del precio por litro, la cantidad de litros y el valor del descuento.
# ######El valor a pagar por un cliente será el resultado de la multiplicación del precio por litro por la cantidad de litros menos el valor del descuento resultante del cálculo.

# %% [markdown]
# ###### Solicitar datos al usuario

# %%
litros = float(input("Ingrese cantidad de litros: "))
tipo = input("Ingrese tipo de combustible (E/D): ").upper()
# Out:
# Ingrese cantidad de litros: 50
# Ingrese tipo de combustible (E/D): D

# %% [markdown]
# ###### Validar tipo de combustible

# %%
if tipo not in ["E", "D"]:
    print("Tipo de combustible inválido")
    exit()

# %% [markdown]
# ###### Establecer precios y descuentos

# %%
if tipo == "E":
    precio = 1.70
    descuento = 0.02 if litros <= 15 else 0.04

# (Diesel)
else:
    precio = 2.00
    descuento = 0.03 if litros <= 15 else 0.05

# %% [markdown]
# ###### Calcular totales

# %%
total_sin_descuento = precio * litros
valor_descuento = total_sin_descuento * descuento
total_pagar = total_sin_descuento - valor_descuento

# %% [markdown]
# ###### Mostrar resultado con formato de moneda

# %%
print(f"El valor a pagar es: R$ {total_pagar:.2f}")
# Out:
# El valor a pagar es: R$ 95.00
